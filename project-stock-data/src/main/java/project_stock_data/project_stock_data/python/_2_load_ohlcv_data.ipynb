# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, MetaData, Integer, String, Date, Float, BigInteger
import psycopg2
import requests
import json

# %%
conn = psycopg2.connect(
  host="localhost",
  database="bc2504p",
  user="postgres",
  password="Admin1234$",
  port="5432"
)

# %%
stock_engine = create_engine("postgresql+psycopg2://postgres:Admin1234$@localhost:5432/bc2504p")
df_sp500_symbols = pd.read_sql("select symbol from stock_data", con=stock_engine)
print(df_sp500_symbols.symbol[59])
print(type(df_sp500_symbols.symbol[1]))
print(len(df_sp500_symbols))
# Out:
# BRK.B
# <class 'str'>
# 503

# %%
stock_table_name = []
for i in range (0, len(df_sp500_symbols)):
  stock_table_name.append("stock_ohlcv_" + str(df_sp500_symbols.symbol[i].lower().replace('.','_')))
#print(stock_table_name)
print(len(stock_table_name))
print(len(df_sp500_symbols))
print(stock_table_name[59])
#for i in range (0, len(stock_table_name)):
 # print(stock_table_name[i])
# Out:
# 503
# 503
# stock_ohlcv_brk_b

# %%
from datetime import date, datetime, timedelta
from io import StringIO
ohlcv_engine = create_engine("postgresql+psycopg2://postgres:Admin1234$@localhost:5432/bc2504p")
metadata = MetaData()
yester_date = datetime.now().date() - timedelta(days=1)
desired_date_time = datetime(yester_date.year, yester_date.month, yester_date.day, 21, 30, 0)
period2 = round(desired_date_time.timestamp())
for i in range (0, len(df_sp500_symbols)):
  stock_schema = Table(
  str(stock_table_name[i]),
  metadata,
  Column('timestamp', Integer, primary_key=True),
  Column('datetime', String(20), nullable=True),
  Column('low', Float(20), nullable=False),
  Column('close', Float(20), nullable=False),
  Column('high', Float(20), nullable=False),
  Column('open', Float(20), nullable=False),
  Column('volume', Integer, nullable=False),
  extend_existing=True
)

  url = str("https://query1.finance.yahoo.com/v8/finance/chart/" + df_sp500_symbols.symbol[i].replace('.','-') + "?period1=1657237004&period2=" + str(period2) + "&interval=1d&events=history")

  # https://query1.finance.yahoo.com/v8/finance/chart/AAPL?period1=1657237004&period2=1752778462&interval=1d&events=history 
  headers = {
  'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
}
  response = requests.get(url, headers=headers)

  df_ohlcv2 = pd.read_json(StringIO(response.text))
  request_time = i + 1
  print(f"request_time={request_time}")
  df_ohlcv = (df_ohlcv2)['chart']['result'][0]['indicators']['quote'][0]
  #print(type(df_ohlcv))
  df_ohlcv['timestamp'] = (df_ohlcv2)['chart']['result'][0]['timestamp']

  date_time = []
  #df_ohlcv['datetime'] = lambda t : datetime.fromtimestamp(df_ohlcv['timestamp'])
  for j in range (0, (len(df_ohlcv['timestamp']))):
    date_time.append(datetime.fromtimestamp(df_ohlcv['timestamp'][j]).strftime("%Y-%m-%d %H:%M:%S"))
    #print(date_time)
  df_ohlcv['datetime'] = date_time
  df_pd_ohlcv = pd.DataFrame(df_ohlcv)
  df_pd_ohlcv.to_sql(str(stock_table_name[i]), ohlcv_engine, index=False, if_exists="replace")
  print(f"table_name={stock_table_name[i]} created.")
  # time.sleep(5)
# Out:
# request_time=1
# table_name=stock_ohlcv_mmm created.
# request_time=2
# table_name=stock_ohlcv_aos created.
# request_time=3
# table_name=stock_ohlcv_abt created.
# request_time=4
# table_name=stock_ohlcv_abbv created.
# request_time=5
# table_name=stock_ohlcv_acn created.
# request_time=6
# table_name=stock_ohlcv_adbe created.
# request_time=7
# table_name=stock_ohlcv_amd created.
# request_time=8
# table_name=stock_ohlcv_aes created.
# request_time=9
# table_name=stock_ohlcv_afl created.
# request_time=10
# table_name=stock_ohlcv_a created.
# request_time=11
# table_name=stock_ohlcv_apd created.
# request_time=12
# table_name=stock_ohlcv_abnb created.
# request_time=13
# table_name=stock_ohlcv_akam created.
# request_time=14
# table_name=stock_ohlcv_alb created.
# request_time=15
# table_name=stock_ohlcv_are created.
# request_time=16
# table_name=stock_ohlcv_algn created.
# request_time=17
# table_name=stock_ohlcv_alle created.
# request_time=18
# ...
